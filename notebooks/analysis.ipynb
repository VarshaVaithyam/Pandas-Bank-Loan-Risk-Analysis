# %% [markdown]
# # Bank Loan Risk Analysis
#
# ## Objective
# The objective of this project is to analyze bank loan applicant data to understand customer behavior, identify patterns, and discover factors affecting loan approval and default risk.
#
# ### Tools Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/loan_data.csv")

# %%
df.head()
# Out:
#    candidate_id country                organization  interest_rate  \
# 0  2.680000e+11       Z  Turner, Baldwin and Rhodes          4.250
# 1  6.730000e+11       Y  Swanson, Newton and Miller          4.875
# 2  7.430000e+11       Z              Thornton-Davis          3.250
# 3  6.010000e+11       X                       OTHER          4.750
# 4  2.740000e+11       X                       OTHER          4.750
#
#    unpaid_principal_bal  loan_term origination_date first_payment_date  \
# 0                214000        360       01-03-2012             May-12
# 1                144000        360       01-01-2012             Mar-12
# 2                366000        180       01-01-2012             Mar-12
# 3                135000        360       01-02-2012             Apr-12
# 4                124000        360       01-02-2012             Apr-12
#
#    loan_to_value  number_of_borrowers  ...  E4  E5 E6  E7  E8  E9  E10  E11  \
# ...

# %%
df.shape
# Out:
# (116058, 29)

# %%
df.columns
# Out:
# Index(['candidate_id', 'country', 'organization', 'interest_rate',
#        'unpaid_principal_bal', 'loan_term', 'origination_date',
#        'first_payment_date', 'loan_to_value', 'number_of_borrowers',
#        'debt_to_income_ratio', 'borrower_credit_score', 'loan_purpose',
#        'insurance_percent', 'co-borrower_credit_score', 'insurance_type', 'E1',
#        'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12',
#        'E13'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116058 entries, 0 to 116057
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   candidate_id              116058 non-null  float64
#  1   country                   116058 non-null  object
#  2   organization              116058 non-null  object
#  3   interest_rate             116058 non-null  float64
#  4   unpaid_principal_bal      116058 non-null  int64
#  5   loan_term                 116058 non-null  int64
#  6   origination_date          116058 non-null  object
#  7   first_payment_date        116058 non-null  object
#  8   loan_to_value             116058 non-null  int64
#  9   number_of_borrowers       116058 non-null  int64
#  10  debt_to_income_ratio      116058 non-null  int64
#  11  borrower_credit_score     116058 non-null  int64
#  12  loan_purpose              116058 non-null  object
# ...

# %%
df.describe()
# Out:
#        candidate_id  interest_rate  unpaid_principal_bal      loan_term  \
# count  1.160580e+05  116058.000000          1.160580e+05  116058.000000
# mean   5.494154e+11       3.868961          2.082262e+05     292.280997
# std    2.597569e+11       0.461020          1.146851e+05      89.762415
# min    1.000000e+11       2.250000          1.100000e+04      60.000000
# 25%    3.240000e+11       3.500000          1.200000e+05     180.000000
# 50%    5.490000e+11       3.875000          1.830000e+05     360.000000
# 75%    7.740000e+11       4.125000          2.780000e+05     360.000000
# max    1.000000e+12       6.750000          1.200000e+06     360.000000
#
#        loan_to_value  number_of_borrowers  debt_to_income_ratio  \
# count  116058.000000        116058.000000         116058.000000
# mean       67.431939             1.593186             30.742293
# std        17.291719             0.491242              9.730798
# ...

# %%
df.isnull().sum()
# Out:
# candidate_id                0
# country                     0
# organization                0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# E1                          0
# E2                          0
# E3                          0
# E4                          0
# E5                          0
# E6                          0
# E7                          0
# E8                          0
# E9                          0
# E10                         0
# E11                         0
# E12                         0
# E13                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# candidate_id                901
# country                       3
# organization                 19
# interest_rate               923
# unpaid_principal_bal        646
# loan_term                   140
# origination_date              3
# first_payment_date            4
# loan_to_value                92
# number_of_borrowers           2
# debt_to_income_ratio         58
# borrower_credit_score       221
# loan_purpose                  3
# insurance_percent            14
# co-borrower_credit_score    216
# insurance_type                2
# E1                            4
# E2                            5
# E3                            6
# E4                            7
# E5                            8
# E6                            9
# E7                           10
# E8                           10
# E9                           11
# E10                          12
# E11                          13
# E12                          13
# E13                           2
# ...

# %%
df.isnull().sum()
# Out:
# candidate_id                0
# country                     0
# organization                0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# E1                          0
# E2                          0
# E3                          0
# E4                          0
# E5                          0
# E6                          0
# E7                          0
# E8                          0
# E9                          0
# E10                         0
# E11                         0
# E12                         0
# E13                         0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# candidate_id                0
# country                     0
# organization                0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# E1                          0
# E2                          0
# E3                          0
# E4                          0
# E5                          0
# E6                          0
# E7                          0
# E8                          0
# E9                          0
# E10                         0
# E11                         0
# E12                         0
# E13                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# candidate_id                float64
# country                      object
# organization                 object
# interest_rate               float64
# unpaid_principal_bal          int64
# loan_term                     int64
# origination_date             object
# first_payment_date           object
# loan_to_value                 int64
# number_of_borrowers           int64
# debt_to_income_ratio          int64
# borrower_credit_score         int64
# loan_purpose                 object
# insurance_percent             int64
# co-borrower_credit_score      int64
# insurance_type                int64
# E1                            int64
# E2                            int64
# E3                            int64
# E4                            int64
# E5                            int64
# E6                            int64
# E7                            int64
# E8                            int64
# E9                            int64
# E10                           int64
# ...

# %%
df.columns
# Out:
# Index(['candidate_id', 'country', 'organization', 'interest_rate',
#        'unpaid_principal_bal', 'loan_term', 'origination_date',
#        'first_payment_date', 'loan_to_value', 'number_of_borrowers',
#        'debt_to_income_ratio', 'borrower_credit_score', 'loan_purpose',
#        'insurance_percent', 'co-borrower_credit_score', 'insurance_type', 'E1',
#        'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12',
#        'E13'],
#       dtype='object')

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

# %%
df.columns
# Out:
# Index(['candidate_id', 'country', 'organization', 'interest_rate',
#        'unpaid_principal_bal', 'loan_term', 'origination_date',
#        'first_payment_date', 'loan_to_value', 'number_of_borrowers',
#        'debt_to_income_ratio', 'borrower_credit_score', 'loan_purpose',
#        'insurance_percent', 'co-borrower_credit_score', 'insurance_type', 'e1',
#        'e2', 'e3', 'e4', 'e5', 'e6', 'e7', 'e8', 'e9', 'e10', 'e11', 'e12',
#        'e13'],
#       dtype='object')

# %%
df.nunique()
# Out:
# candidate_id                901
# country                       3
# organization                 19
# interest_rate               923
# unpaid_principal_bal        646
# loan_term                   140
# origination_date              3
# first_payment_date            4
# loan_to_value                92
# number_of_borrowers           2
# debt_to_income_ratio         58
# borrower_credit_score       221
# loan_purpose                  3
# insurance_percent            14
# co-borrower_credit_score    216
# insurance_type                2
# e1                            4
# e2                            5
# e3                            6
# e4                            7
# e5                            8
# e6                            9
# e7                           10
# e8                           10
# e9                           11
# e10                          12
# e11                          13
# e12                          13
# e13                           2
# ...

# %%
df["loan_to_value"].value_counts()
# Out:
# loan_to_value
# 80    22364
# 75     8231
# 95     4374
# 70     3393
# 90     3303
#       ...
# 10       28
# 9        11
# 8        10
# 7         8
# 6         5
# Name: count, Length: 92, dtype: int64

# %%
df["loan_to_value"].value_counts()
# Out:
# loan_to_value
# 80    22364
# 75     8231
# 95     4374
# 70     3393
# 90     3303
#       ...
# 10       28
# 9        11
# 8        10
# 7         8
# 6         5
# Name: count, Length: 92, dtype: int64

# %%
import matplotlib.pyplot as plt

df["loan_to_value"].value_counts().plot(kind="bar")
plt.title("Loan-to-Value Distribution")
plt.xlabel("Loan-to-Value")
plt.ylabel("Count")
plt.show()

# %%
df.describe()
# Out:
#        candidate_id  interest_rate  unpaid_principal_bal      loan_term  \
# count  1.160580e+05  116058.000000          1.160580e+05  116058.000000
# mean   5.494154e+11       3.868961          2.082262e+05     292.280997
# std    2.597569e+11       0.461020          1.146851e+05      89.762415
# min    1.000000e+11       2.250000          1.100000e+04      60.000000
# 25%    3.240000e+11       3.500000          1.200000e+05     180.000000
# 50%    5.490000e+11       3.875000          1.830000e+05     360.000000
# 75%    7.740000e+11       4.125000          2.780000e+05     360.000000
# max    1.000000e+12       6.750000          1.200000e+06     360.000000
#
#        loan_to_value  number_of_borrowers  debt_to_income_ratio  \
# count  116058.000000        116058.000000         116058.000000
# mean       67.431939             1.593186             30.742293
# std        17.291719             0.491242              9.730798
# ...

# %%
df.hist(figsize=(15,10))
plt.show()

# %%
corr = df.corr(numeric_only=True)

import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.describe().T
# Out:
#                              count          mean           std           min  \
# candidate_id              116058.0  5.494154e+11  2.597569e+11  1.000000e+11
# interest_rate             116058.0  3.868961e+00  4.610200e-01  2.250000e+00
# unpaid_principal_bal      116058.0  2.082262e+05  1.146851e+05  1.100000e+04
# loan_term                 116058.0  2.922810e+02  8.976241e+01  6.000000e+01
# loan_to_value             116058.0  6.743194e+01  1.729172e+01  6.000000e+00
# number_of_borrowers       116058.0  1.593186e+00  4.912417e-01  1.000000e+00
# debt_to_income_ratio      116058.0  3.074229e+01  9.730798e+00  1.000000e+00
# borrower_credit_score     116058.0  7.699268e+02  4.221071e+01  0.000000e+00
# insurance_percent         116058.0  2.786288e+00  8.096464e+00  0.000000e+00
# co-borrower_credit_score  116058.0  4.596116e+02  3.819469e+02  0.000000e+00
# insurance_type            116058.0  3.256992e-03  5.697730e-02  0.000000e+00
# ...

# %%
df.describe(include="object").T
# Out:
#                      count unique         top   freq
# country             116058      3           X  63858
# organization        116058     19       OTHER  49699
# origination_date    116058      3  01-02-2012  52334
# first_payment_date  116058      4      Apr-12  52840
# loan_purpose        116058      3         A23  58462

# %%
df.head()
# Out:
#    candidate_id country                organization  interest_rate  \
# 0  2.680000e+11       Z  Turner, Baldwin and Rhodes          4.250
# 1  6.730000e+11       Y  Swanson, Newton and Miller          4.875
# 2  7.430000e+11       Z              Thornton-Davis          3.250
# 3  6.010000e+11       X                       OTHER          4.750
# 4  2.740000e+11       X                       OTHER          4.750
#
#    unpaid_principal_bal  loan_term origination_date first_payment_date  \
# 0                214000        360       01-03-2012             May-12
# 1                144000        360       01-01-2012             Mar-12
# 2                366000        180       01-01-2012             Mar-12
# 3                135000        360       01-02-2012             Apr-12
# 4                124000        360       01-02-2012             Apr-12
#
#    loan_to_value  number_of_borrowers  ...  e4  e5 e6  e7  e8  e9  e10  e11  \
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["interest_rate"], bins=30, kde=True)
plt.title("Distribution of Interest Rate")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["unpaid_principal_bal"], bins=30, kde=True)
plt.title("Distribution of Unpaid Principal Balance")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["borrower_credit_score"], bins=30, kde=True)
plt.title("Borrower Credit Score Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="country", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="loan_purpose", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="borrower_credit_score",
    y="interest_rate",
    data=df
)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="unpaid_principal_bal",
    y="interest_rate",
    data=df
)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=df["interest_rate"])
plt.show()

# %%
sns.boxplot(x=df["unpaid_principal_bal"])
plt.show()

# %%
sns.boxplot(x=df["borrower_credit_score"])
plt.show()

# %%
df.groupby("loan_purpose")["interest_rate"].mean().sort_values()
# Out:
# loan_purpose
# A23    3.780996
# B12    3.852446
# C86    4.068437
# Name: interest_rate, dtype: float64

# %%
df.groupby("country")["unpaid_principal_bal"].mean().sort_values()
# Out:
# country
# X    197974.349338
# Y    212079.858337
# Z    243044.244162
# Name: unpaid_principal_bal, dtype: float64

# %%
df.groupby("organization")["borrower_credit_score"].mean().sort_values()
# Out:
# organization
# Cole, Brooks and Vincent       762.233252
# Turner, Baldwin and Rhodes     764.340195
# Miller, Mcclure and Allen      764.878721
# Taylor, Hunt and Rodriguez     767.444797
# Nicholson Group                767.712665
# Anderson-Taylor                768.269151
# OTHER                          769.191231
# Martinez, Duffy and Bird       770.350795
# Edwards-Hoffman                770.504632
# Browning-Hart                  770.586839
# Swanson, Newton and Miller     771.090340
# Richardson Ltd                 771.659619
# Romero, Woods and Johnson      773.376000
# Suarez Inc                     775.534078
# Sanchez-Robinson               776.595138
# Richards-Walters               777.300891
# Sanchez, Hays and Wilkerson    778.740914
# Chapman-Mcmahon                779.298969
# Thornton-Davis                 780.545315
# Name: borrower_credit_score, dtype: float64
